# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime

# %%
fitbit = pd.read_csv('Yearfit.csv')

# %%
fitbit.head(10)
# Out:
#         Date  Calories    Steps Distance  floors  Minutes_sitting  \
# 0 2015-08-05     1.934  905.000     0,65       0            1.355
# 1 2015-09-05     3.631   18.925    14,11       4          611.000
# 2 2015-10-05     3.204   14.228    10,57       1          602.000
# 3 2015-11-05     2.673    6.756     5,02       8          749.000
# 4 2015-12-05     2.495    5.020     3,73       1          876.000
# 5 2015-05-13     2.760    7.790     5,79      15          726.000
# 6 2015-05-14     2.687    5.614     4,17       2          782.000
# 7 2015-05-15     2.793    8.169     6,07      14          801.000
# 8 2015-05-16     4.061   19.971    14,84      18          532.000
# 9 2015-05-17     3.349    8.520     6,33      12          606.000
#
#    Minutes_of_slow_activity  Minutes_of_moderate_activity  \
# 0                        46                             0
# 1                       316                            61
# 2                       226                            14
# ...

# %%
fitbit['Date'] = pd.to_datetime(fitbit['Date'])

# %%
weekly = fitbit.set_index('Date').resample('W')

# %%
weekly.sum()
# Out:
#             Calories    Steps  floors  Minutes_sitting  \
# Date
# 2015-01-11    18.947   72.568      73         3501.092
# 2015-01-18     3.232   16.810      14          750.000
# 2015-01-25     0.000    0.000       0            0.000
# 2015-02-01     0.000    0.000       0            0.000
# 2015-02-08     9.083   33.269      67         1892.000
# 2015-02-15    11.533   35.867      47         2206.279
# 2015-02-22     0.000    0.000       0            0.000
# 2015-03-01     0.000    0.000       0            0.000
# 2015-03-08    10.053   45.330      49         2052.000
# 2015-03-15    10.984   35.555      34          777.788
# 2015-03-22     0.000    0.000       0            0.000
# 2015-03-29     0.000    0.000       0            0.000
# 2015-04-05     0.000    0.000       0            0.000
# 2015-04-12    20.816   74.555      91         3433.236
# 2015-04-19     0.000    0.000       0            0.000
# 2015-04-26     0.000    0.000       0            0.000
# ...

# %%
dir(weekly)
# Out:
# ['Calories',
#  'Calories_Activity',
#  'Distance',
#  'Minutes_of_intense_activity',
#  'Minutes_of_moderate_activity',
#  'Minutes_of_slow_activity',
#  'Minutes_sitting',
#  'Steps',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_accessors',
#  '_adjust_binner_for_upsample',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_apply_filter',
#  '_apply_loffset',
#  '_apply_whitelist',
#  '_assure_grouper',
#  '_attributes',
#  '_builtin_table',
# ...

# %%
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 10 columns):
# Date                            367 non-null object
# Calories                        367 non-null float64
# Steps                           367 non-null float64
# Distance                        367 non-null object
# floors                          367 non-null int64
# Minutes_sitting                 367 non-null float64
# Minutes_of_slow_activity        367 non-null int64
# Minutes_of_moderate_activity    367 non-null int64
# Minutes_of_intense_activity     367 non-null int64
# Calories_Activity               367 non-null float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 28.8+ KB

# %%
fitbit.describe()
# Out:
#          Calories       Steps      floors  Minutes_sitting  \
# count  367.000000  367.000000  367.000000       367.000000
# mean     3.036858   13.991343   11.724796       563.934482
# std      0.405912   46.866915   10.337370       294.793145
# min      1.789000    0.000000    0.000000         1.002000
# 25%      2.808500    8.339500    5.000000       520.000000
# 50%      3.040000   11.199000   11.000000       663.000000
# 75%      3.256500   14.227000   16.000000       756.500000
# max      4.351000  905.000000  101.000000       998.000000
#
#        Minutes_of_slow_activity  Minutes_of_moderate_activity  \
# count                367.000000                    367.000000
# mean                 236.405995                     26.163488
# std                   86.531376                     20.319456
# min                    0.000000                      0.000000
# 25%                  179.000000                      8.000000
# ...

# %%
sns.pairplot(fitbit)

# %%
sns.heatmap(fitbit.corr())

# %%
fitbit.columns
# Out:
# Index(['Date', 'Calories', 'Steps', 'Distance', 'floors', 'Minutes_sitting',
#        'Minutes_of_slow_activity', 'Minutes_of_moderate_activity',
#        'Minutes_of_intense_activity', 'Calories_Activity'],
#       dtype='object')

# %%
df = pd.DataFrame(fitbit)

# %%
df.head()
# Out:
#         Date  Calories    Steps Distance  floors  Minutes_sitting  \
# 0 2015-08-05     1.934  905.000     0,65       0            1.355
# 1 2015-09-05     3.631   18.925    14,11       4          611.000
# 2 2015-10-05     3.204   14.228    10,57       1          602.000
# 3 2015-11-05     2.673    6.756     5,02       8          749.000
# 4 2015-12-05     2.495    5.020     3,73       1          876.000
#
#    Minutes_of_slow_activity  Minutes_of_moderate_activity  \
# 0                        46                             0
# 1                       316                            61
# 2                       226                            14
# 3                       190                            23
# 4                       171                             0
#
#    Minutes_of_intense_activity  Calories_Activity
# 0                            0            168.000
# 1                           60              2.248
# 2                           77              1.719
# ...

# %%
df.drop(columns=['floors', 'Distance','Minutes_sitting','Minutes_of_slow_activity','Minutes_of_intense_activity','Calories_Activity','Minutes_of_moderate_activity'])
# Out:
#           Date  Calories    Steps
# 0   2015-08-05     1.934  905.000
# 1   2015-09-05     3.631   18.925
# 2   2015-10-05     3.204   14.228
# 3   2015-11-05     2.673    6.756
# 4   2015-12-05     2.495    5.020
# 5   2015-05-13     2.760    7.790
# 6   2015-05-14     2.687    5.614
# 7   2015-05-15     2.793    8.169
# 8   2015-05-16     4.061   19.971
# 9   2015-05-17     3.349    8.520
# 10  2015-05-18     2.961   11.998
# 11  2015-05-19     2.911   12.425
# 12  2015-05-20     2.569    6.008
# 13  2015-05-21     3.228   16.291
# 14  2015-05-22     2.529    6.111
# 15  2015-05-23     4.197   17.928
# 16  2015-05-24     3.899   13.893
# 17  2015-05-25     2.519    5.109
# 18  2015-05-26     2.357    4.430
# 19  2015-05-27     3.209    7.498
# 20  2015-05-28     2.811    8.490
# 21  2015-05-29     2.558    5.650
# 22  2015-05-30     4.170   21.479
# 23  2015-05-31     3.533   18.995
# 24  2015-01-06     3.354   16.836
# 25  2015-02-06     3.369   15.944
# ...

# %%
df1 = weekly.sum()

# %%
df1.head()
# Out:
#             Calories   Steps  floors  Minutes_sitting  \
# Date
# 2015-01-11    18.947  72.568      73         3501.092
# 2015-01-18     3.232  16.810      14          750.000
# 2015-01-25     0.000   0.000       0            0.000
# 2015-02-01     0.000   0.000       0            0.000
# 2015-02-08     9.083  33.269      67         1892.000
#
#             Minutes_of_slow_activity  Minutes_of_moderate_activity  \
# Date
# 2015-01-11                      1455                           193
# 2015-01-18                       152                             9
# 2015-01-25                         0                             0
# 2015-02-01                         0                             0
# 2015-02-08                       617                            46
#
#             Minutes_of_intense_activity  Calories_Activity
# Date
# 2015-01-11                          210            669.643
# 2015-01-18                           97              1.618
# ...

# %%
dfs = df1[['Calories', 'Steps']]

# %%
dfs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b4ba2fa0b5dc> in <module>
# ----> 1 dfs
#
# NameError: name 'dfs' is not defined

# %%
sns.heatmap(dfs.corr())

# %%
date_va = dfs.index.values

# %%
dfs.set_index('idx')
# Out:
#      Calories    Steps
# idx
# 1      18.947   72.568
# 2       3.232   16.810
# 3       0.000    0.000
# 4       0.000    0.000
# 5       9.083   33.269
# 6      11.533   35.867
# 7       0.000    0.000
# 8       0.000    0.000
# 9      10.053   45.330
# 10     10.984   35.555
# 11      0.000    0.000
# 12      0.000    0.000
# 13      0.000    0.000
# 14     20.816   74.555
# 15      0.000    0.000
# 16      0.000    0.000
# 17      0.000    0.000
# 18     15.719   64.233
# 19     21.373   66.711
# 20     22.294   84.654
# 21     21.157   71.651
# 22      6.135   23.871
# 23     21.959   91.280
# 24     23.137  106.390
# 25     22.385   97.521
# 26      6.087   25.031
# 27     21.527   79.455
# 28     23.045   88.649
# 29     21.637   80.861
# 30     15.109   57.439
# ..        ...      ...
# 71      0.000    0.000
# 72      0.000    0.000
# 73      0.000    0.000
# 74     16.480   73.174
# 75      0.000    0.000
# 76      0.000    0.000
# 77      0.000    0.000
# ...

# %%
dfs['date'] = date_va
# Out:
# C:\Users\Parth Kaushik\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfs_date = dfs.drop(columns=['idx'])

# %%
dfs_date.head()
# Out:
#             Calories   Steps       date
# Date
# 2015-01-11    18.947  72.568 2015-01-11
# 2015-01-18     3.232  16.810 2015-01-18
# 2015-01-25     0.000   0.000 2015-01-25
# 2015-02-01     0.000   0.000 2015-02-01
# 2015-02-08     9.083  33.269 2015-02-08

# %%
sns.jointplot(x='Date',y='Steps',data=fitbit)
# Out:
# C:\Users\Parth Kaushik\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-d002139ccb44> in <module>
# ----> 1 sns.jointplot(x='Date',y='Steps',data=fitbit)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
# ...

# %%
dfs['idx'] = list(range(1, 101))
# Out:
# C:\Users\Parth Kaushik\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
d = dfs.reindex('idx')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-36f0c3179c54> in <module>
# ----> 1 d = dfs.reindex('idx')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     195         @wraps(func)
#     196         def wrapper(*args, **kwargs):
# --> 197             return func(*args, **kwargs)
#     198
#     199         if not PY2:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3807         kwargs.pop('axis', None)
#    3808         kwargs.pop('labels', None)
# -> 3809         return super(DataFrame, self).reindex(**kwargs)
#    3810
#    3811     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4354         # perform the reindex on the axes
# ...

# %%
d
# Out:
#      Calories    Steps
# idx
# 1      18.947   72.568
# 2       3.232   16.810
# 3       0.000    0.000
# 4       0.000    0.000
# 5       9.083   33.269
# 6      11.533   35.867
# 7       0.000    0.000
# 8       0.000    0.000
# 9      10.053   45.330
# 10     10.984   35.555
# 11      0.000    0.000
# 12      0.000    0.000
# 13      0.000    0.000
# 14     20.816   74.555
# 15      0.000    0.000
# 16      0.000    0.000
# 17      0.000    0.000
# 18     15.719   64.233
# 19     21.373   66.711
# 20     22.294   84.654
# 21     21.157   71.651
# 22      6.135   23.871
# 23     21.959   91.280
# 24     23.137  106.390
# 25     22.385   97.521
# 26      6.087   25.031
# 27     21.527   79.455
# 28     23.045   88.649
# 29     21.637   80.861
# 30     15.109   57.439
# ..        ...      ...
# 71      0.000    0.000
# 72      0.000    0.000
# 73      0.000    0.000
# 74     16.480   73.174
# 75      0.000    0.000
# 76      0.000    0.000
# 77      0.000    0.000
# ...
